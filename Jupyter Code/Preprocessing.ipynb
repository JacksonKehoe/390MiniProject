# %%
import pandas as pd;
import requests
from sklearn.preprocessing import StandardScaler

# %%
NYSE = pd.read_csv('../Processed Data/NYSETickers.csv');

# %%
display(NYSE);
# Out:
#                                                 Company Ticker  \
# 0                   AGILENT TECHNOLOGIES, INC. (XNYS:A)      A
# 1                           ALCOA CORPORATION (XNYS:AA)     AA
# 2          Arlington Asset Investment Corp. (XNYS:AAIC)   AAIC
# 3                   ADVANCE AUTO PARTS, INC. (XNYS:AAP)    AAP
# 4                AMERICAN ASSETS TRUST, INC. (XNYS:AAT)    AAT
# ...                                                 ...    ...
# 1353                     ALLEGHANY CORPORATION (XNYS:Y)      Y
# 1354                      Yiren Digital Ltd. (XNYS:YRD)    YRD
# 1355            ZIMMER BIOMET HOLDINGS, INC. (XNYS:ZBH)    ZBH
# 1356  China Southern Airlines Company Limited (XNYS:...    ZNH
# 1357                         ZYMEWORKS INC. (XNYS:ZYME)   ZYME
#
#                  Sector Last Sale  Net Change % Change    Market Cap   Volume  \
# 0         Capital Goods   $124.83       0.350    0.28%  3.812175e+10   528837
# ...

# %%
technology = NYSE.loc[NYSE['Sector'] == "Technology"];

# %%
display(technology);
# Out:
#                                           Company Ticker      Sector  \
# 31                  AerCap Holdings NV (XNYS:AER)    AER  Technology
# 65                AIR LEASE CORPORATION (XNYS:AL)     AL  Technology
# 81       AMN HEALTHCARE SERVICES, INC. (XNYS:AMN)    AMN  Technology
# 90              ARISTA NETWORKS, INC. (XNYS:ANET)   ANET  Technology
# 108   EVOQUA WATER TECHNOLOGIES CORP. (XNYS:AQUA)   AQUA  Technology
# ...                                           ...    ...         ...
# 1282                UNISYS CORPORATION (XNYS:UIS)    UIS  Technology
# 1286              UNITED RENTALS, INC. (XNYS:URI)    URI  Technology
# 1303               VEEVA SYSTEMS INC. (XNYS:VEEV)   VEEV  Technology
# 1331                       WORKIVA INC. (XNYS:WK)     WK  Technology
# 1341                           WPP PLC (XNYS:WPP)    WPP  Technology
#
#      Last Sale  Net Change % Change    Market Cap  Volume 52 wk high  \
# ...

# %%
finance = NYSE.loc[NYSE['Sector'] == "Finance"];

# %%
display(finance);
# Out:
#                                                 Company Ticker   Sector  \
# 9                ABM INDUSTRIES INCORPORATED (XNYS:ABM)    ABM  Finance
# 12             ASSOCIATED CAPITAL GROUP, INC. (XNYS:AC)     AC  Finance
# 24                                  Aegon NV (XNYS:AEB)    AEB  Finance
# 26                                  Aegon NV (XNYS:AEG)    AEG  Finance
# 27    AMERICAN EQUITY INVESTMENT LIFE HOLDING COMPAN...    AEL  Finance
# ...                                                 ...    ...      ...
# 1327               Woori Financial Group Inc. (XNYS:WF)     WF  Finance
# 1329           WESTWOOD HOLDINGS GROUP, INC. (XNYS:WHG)    WHG  Finance
# 1342               W. R. BERKLEY CORPORATION (XNYS:WRB)    WRB  Finance
# 1353                     ALLEGHANY CORPORATION (XNYS:Y)      Y  Finance
# 1354                      Yiren Digital Ltd. (XNYS:YRD)    YRD  Finance
#
#      Last Sale  Net Change % Change    Market Cap   Volume 52 wk high  \
# ...

# %%
health = NYSE.loc[NYSE['Sector'] == "Health Care"];
display(health);
# Out:
#                                          Company Ticker       Sector  \
# 6                        ABBVIE INC. (XNYS:ABBV)   ABBV  Health Care
# 7       AMERISOURCEBERGEN CORPORATION (XNYS:ABC)    ABC  Health Care
# 11                ABBOTT LABORATORIES (XNYS:ABT)    ABT  Health Care
# 86      AMNEAL PHARMACEUTICALS, INC. (XNYS:AMRX)   AMRX  Health Care
# 93                      ANTHEM, INC. (XNYS:ANTM)   ANTM  Health Care
# ...                                          ...    ...          ...
# 1279  UNIVERSAL HEALTH SERVICES, INC. (XNYS:UHS)    UHS  Health Care
# 1289    U. S. PHYSICAL THERAPY, INC. (XNYS:USPH)   USPH  Health Care
# 1299     VARIAN MEDICAL SYSTEMS, INC. (XNYS:VAR)    VAR  Health Care
# 1355     ZIMMER BIOMET HOLDINGS, INC. (XNYS:ZBH)    ZBH  Health Care
# 1357                  ZYMEWORKS INC. (XNYS:ZYME)   ZYME  Health Care
#
#      Last Sale  Net Change % Change    Market Cap   Volume 52 wk high  \
# ...

# %%
finance.to_csv("../Processed Data/Finance_only.csv");
